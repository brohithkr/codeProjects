# %% [markdown]
# <a href="https://colab.research.google.com/github/brohithkr/codeProjects/blob/main/aimlWorkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("car_data.csv")

# %%
data = pd.read_csv("car_data.csv")
prices = data['Price']
notnumbool = []
totsum = 0
for s in range(len(prices)):
    temp = ""
    tempbool = False
    prices[s] = prices[s].strip()
    for c in prices[s]:
        if c.isdigit():
            temp += c
        elif c!="," and c!=" ":
            tempbool = True
    
    prices[s] = int(temp) if type(temp) == int else temp
    # totsum+= 


    # prices[s] = prices[s]
    notnumbool.append(tempbool)
npnotnumbool = np.array(notnumbool)
# for i in range(len(prices)):
#     prices[i] = int(prices[i])
# prices[~npnotnumbool]

# %%
car = pd.read_csv('cleaned_car.csv')

x = car['kms_driven']
y = car['Price']

plt.scatter(x=x,y=y)
plt.savefig('textpic_kmvscost.svg')
