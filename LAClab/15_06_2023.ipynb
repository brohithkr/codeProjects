# %%
import numpy as np
# import scipy.linalg.eig as eig
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 import numpy as np
# ----> 2 import scipy.linalg.eig
#
# ModuleNotFoundError: No module named 'scipy.linalg.eig'

# %%
a = np.array(
    [
        [3,-1],
        [1,3],
        [1,1]
    ]
)

innerProduct = a.T @ a
eigval, eigvec = eig(innerProduct)
print(eigvec)
# Out:
# [12. 10.] [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
from numpy import array
from scipy.linalg import svd
A = array(
    [
        [1,2],
        [3,4],
        [5,6]
    ]
)

print("A:",A,sep="\n")
U, s, Vt = svd(A)
print("U:",U,sep="\n")
print("s:",s,sep="\n")
print("Vt:",Vt,sep="\n")
# Out:
# A:
# [[1 2]
#  [3 4]
#  [5 6]]
# U:
# [[-0.2298477   0.88346102  0.40824829]
#  [-0.52474482  0.24078249 -0.81649658]
#  [-0.81964194 -0.40189603  0.40824829]]
# s:
# [9.52551809 0.51430058]
# Vt:
# [[-0.61962948 -0.78489445]
#  [-0.78489445  0.61962948]]

# %%
a = np.array(
    [
        [.8,.3],
        [.2,.7]
    ]
)
u0 = np.array(
    [0,1]
)
nparr = []
nparr.append(u0)
for i in range(1,100):
    u = a @ nparr[i-1]
    nparr.append(u)
    plt.plot(u[0],u[1],'o')
plt.savefig('temp.svg')
